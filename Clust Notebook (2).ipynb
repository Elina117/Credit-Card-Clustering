# %% [markdown]
# # Импорт необходимых библиотек

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
from sklearn.cluster import Birch
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from scipy.stats import shapiro, f_oneway, kruskal, mannwhitneyu

# %% [markdown]
# # Описание данных

# %% [markdown]
# - **CUST_ID**: Идентификатор держателя кредитной карты (категориальный признак)
#
# - **BALANCE**: Остаток средств на счёте, доступных для покупок
#
# - **BALANCE_FREQUENCY**: Частота обновления баланса (значение от 0 до 1, где 1 = часто обновляется)
#
# - **PURCHASES**: Общая сумма покупок, совершённых с карты
#
# - **ONEOFF_PURCHASES**: Максимальная сумма одной покупки
#
# - **INSTALLMENTS_PURCHASES**: Сумма покупок, оплаченных в рассрочку
#
# - **CASH_ADVANCE**: Сумма, выданная пользователю в виде аванса наличными
#
# - **PURCHASES_FREQUENCY**: Частота совершения покупок (от 0 до 1)
#
# - **ONEOFF_PURCHASES_FREQUENCY**: Частота крупных (разовых) покупок (от 0 до 1)
#
# - **PURCHASES_INSTALLMENTS_FREQUENCY**: Частота покупок в рассрочку (от 0 до 1)
#
# - **CASH_ADVANCE_FREQUENCY**: Частота получения аванса наличными (от 0 до 1)
#
# - **CASH_ADVANCE_TRX**: Количество транзакций с авансом наличными
#
# - **PURCHASES_TRX**: Количество покупок (транзакций)
#
# - **CREDIT_LIMIT**: Кредитный лимит пользователя
#
# - **PAYMENTS**: Общая сумма платежей, произведённых пользователем
#
# - **MINIMUM_PAYMENTS**: Минимальная сумма, оплаченная пользователем
#
# - **PRC_FULL_PAYMENT**: Процент, уплаченный полностью от общей задолженности
#
# - **TENURE**: Срок обслуживания пользователя (в месяцах)

# %%
df = pd.read_csv('CC GENERAL.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
df.drop(columns='CUST_ID', inplace=True)

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# ### Заполняю одно пропущенное значение меиданой, а в MINIMUM_PAYMENTS пропущенные значения предсказываю с помощью линейной регрессии

# %%
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median())

# %%
train_df = df[df['MINIMUM_PAYMENTS'].notna()]
predict_df = df[df['MINIMUM_PAYMENTS'].isna()]

features = df.columns.drop('MINIMUM_PAYMENTS')

X_train = train_df[features]
y_train = train_df['MINIMUM_PAYMENTS']

X_predict = predict_df[features]

model = LinearRegression()
model.fit(X_train, y_train)

predicted_values = model.predict(X_predict)

df.loc[df['MINIMUM_PAYMENTS'].isna(), 'MINIMUM_PAYMENTS'] = predicted_values

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ### Визуализирую разбросы данных для каждой фичи

# %%
columns = df.columns
sns.set(style="whitegrid")

plt.figure(figsize=(15, 10))
for i, col in enumerate(columns, 1):
    plt.subplot((len(columns) + 3) // 4, 4, i)  
    sns.boxplot(y=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Визуализация распределения данных для каждой фичи

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(15, 10))
for i, col in enumerate(columns, 1):
    plt.subplot((len(columns) + 3) // 4, 4, i) 
    sns.kdeplot(x=df[col], fill=True)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Удаляю сильные выбросы, ориентируясь на интерквартальный размах

# %%
def remove_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1 #интерквартальный размах
    df = df[~((df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR)))] #фильтруем значения, которые не являются выбросами
    return df

for col in columns:
    if col!='TENURE':
        df = remove_outliers(df, col)
    
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 4      817.714335           1.000000      16.00             16.00
# 7     1823.652743           1.000000     436.20              0.00
# 8     1014.926473           1.000000     861.49            661.49
# 14    2772.772734           1.000000       0.00              0.00
# ...           ...                ...        ...               ...
# 8942    40.829749           1.000000     113.28              0.00
# 8944   193.571722           0.833333    1012.73           1012.73
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 4                       0.00      0.000000             0.083333
# 7                     436.20      0.000000             1.000000
# 8                     200.00      0.000000             0.333333
# 14                      0.00    346.811390             0.000000
# ...                      ...           ...                  ...
# 8942                  113.28      0.000000             1.000000
# 8944                    0.00      0.000000             0.333333
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 4                       0.083333                          0.000000
# 7                       0.000000                          1.000000
# 8                       0.083333                          0.250000
# 14                      0.000000                          0.000000
# ...                          ...                               ...
# 8942                    0.000000                          0.833333
# 8944                    0.333333                          0.000000
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 4                   0.000000                 0              1        1200.0
# 7                   0.000000                 0             12        2300.0
# 8                   0.000000                 0              5        7000.0
# 14                  0.083333                 1              0        3000.0
# ...                      ...               ...            ...           ...
# 8942                0.000000                 0              6        1000.0
# 8944                0.000000                 0              2        4000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0     201.802084        139.509787              0.00      12
# 4     678.334763        244.791237              0.00      12
# 7     679.065082        532.033990              0.00      12
# 8     688.278568        311.963409              0.00      12
# 14    805.647974        989.962866              0.00      12
# ...          ...               ...               ...     ...
# 8942   94.488828         86.283101              0.25       6
# 8944    0.000000       -149.714350              0.00       6
# 8946  275.861322        438.442488              0.00       6
# 8947   81.270775         82.418369              0.25       6
# 8948   52.549959         55.755628              0.25       6
#
# [2440 rows x 17 columns]

# %% [markdown]
# ### Визуализирую матрицу корреляции

# %%
corr_matrix = df.corr(method='kendall')

plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Если модуль корреляции между признаками больше 0.85, то удаляем один из признаков, рассмотрев триугольный вид матрицы

# %%
corr_matrix = df.corr(method='kendall').abs()

upper_triangle = np.triu(np.ones(corr_matrix.shape), k=1)
upper_triangle_corr = pd.DataFrame(upper_triangle * corr_matrix, 
                                   columns=corr_matrix.columns, 
                                   index=corr_matrix.index)


to_drop = [column for column in upper_triangle_corr.columns 
           if any(upper_triangle_corr[column] > 0.8)]

# Удаляем выбранные признаки
df = df.drop(columns=to_drop)

print(f"Удаленные признаки: {to_drop}")
# Out:
# Удаленные признаки: ['ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX']

# %% [markdown]
# ### Удаляем константные и квазиконстантные признаки

# %%
selector = VarianceThreshold(threshold=0.001)

selector.fit(df)

remaining_features = df.columns[selector.get_support()]

final_columns = list(remaining_features)

columns = df.columns

delete_col = []

for col in columns:
    if col not in final_columns:
        delete_col.append(col)


print(f"Удаленные признаки: {delete_col}")
# Out:
# Удаленные признаки: []

# %% [markdown]
# ### Стандартизируем данные (приводим к нормальному распределению со средним значением 0 и стандартным отклонением 1), так как модели кластеризации и PCA чувствительны к масштабу признаков

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df)

# %%
X.shape
# Out:
# (2440, 13)

# %% [markdown]
# # K-means

# %% [markdown]
# В этом методе нужно заранее решить, сколько кластером хотим выделить и случайным образом иннициализируются центры кластеров. После этого рекурсивно повторяется алгоритм: каждом точке присваиваем тот кластер, чей центр ближе; пересчитываем центры классов в направление центра масс. (Подсчитывается евклидово расстояние)

# %%
best_score = -1
best_k = None
best_labels = None
results = []

for k in range(2, 16): 
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    results.append((k, score))
    if score > best_score:
        best_score = score
        best_k = k
        best_labels = labels

print(f"Лучший Silhouette: {best_score:.4f} при k={best_k}")

mask = best_labels != -1
ch_score = calinski_harabasz_score(X[mask], best_labels[mask])

print(f"Calinski-Harabasz Score: {ch_score:.2f}")
# Out:
# Лучший Silhouette: 0.1880 при k=2
# Calinski-Harabasz Score: 531.35

# %% [markdown]
# ### With two PCA features

# %% [markdown]
# Посмотрим, как сработал алгоритм на двух фичах и визуализируем

# %%
X_pca = PCA(n_components=2).fit_transform(X)

plt.scatter(X_pca[:,0], X_pca[:,1], c=best_labels, cmap='tab10', s=15)
plt.title('KMeans Clusters (k=2) на PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %% [markdown]
# ## Визуализация влияния признаков на работу модели

# %% [markdown]
# Для двух кластеров (k=2)

# %%
k = 2
kmeans = KMeans(n_clusters=k, random_state=42)
df[f'Cluster_{k}'] = kmeans.fit_predict(X)

features_to_plot = [col for col in df.columns if col not in ['CUST_ID', f'Cluster_{k}']]

for feature in features_to_plot:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    sns.boxplot(data=df, x=f'Cluster_{k}', y=feature, ax=axes[0])
    axes[0].set_title(f'Boxplot: {feature} (k={k})')
    axes[0].grid(True)

    sns.barplot(data=df, x=f'Cluster_{k}', y=feature, ax=axes[1], estimator='mean', errorbar=None)
    axes[1].set_title(f'Mean Barplot: {feature} (k={k})')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Для трех кластеров (k=3)

# %%
k = 3 
kmeans = KMeans(n_clusters=k, random_state=42)
df[f'Cluster_{k}'] = kmeans.fit_predict(X)

features_to_plot = [col for col in df.columns if col not in ['CUST_ID', f'Cluster_{k}']]

for feature in features_to_plot:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    sns.boxplot(data=df, x=f'Cluster_{k}', y=feature, ax=axes[0])
    axes[0].set_title(f'Boxplot: {feature} (k={k})')
    axes[0].grid(True)

    sns.barplot(data=df, x=f'Cluster_{k}', y=feature, ax=axes[1], estimator='mean', errorbar=None)
    axes[1].set_title(f'Mean Barplot: {feature} (k={k})')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Интерпретация результатов:
#
#     - Boxplot показывает распределение признака внутри каждого кластера (медиана, размах, вариативность).
#     - Barplot показывает среднее значение признака для каждого признака для каждого кластера, отличие по среднему значению.
#
# #### Разное поведение можно наблюдать по следующим признакам:
#     - если ящики сильно различаются, то признак хорошо разделяет кластеры
#     - если разница средних большая, то признак информативен для кластеризации

# %% [markdown]
# # ANOVA - дисперсионный анализ

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 4      817.714335           1.000000      16.00             16.00
# 7     1823.652743           1.000000     436.20              0.00
# 8     1014.926473           1.000000     861.49            661.49
# 14    2772.772734           1.000000       0.00              0.00
# ...           ...                ...        ...               ...
# 8942    40.829749           1.000000     113.28              0.00
# 8944   193.571722           0.833333    1012.73           1012.73
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 4                       0.00      0.000000             0.083333
# 7                     436.20      0.000000             1.000000
# 8                     200.00      0.000000             0.333333
# 14                      0.00    346.811390             0.000000
# ...                      ...           ...                  ...
# 8942                  113.28      0.000000             1.000000
# 8944                    0.00      0.000000             0.333333
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
#
#       CASH_ADVANCE_FREQUENCY  CREDIT_LIMIT    PAYMENTS  MINIMUM_PAYMENTS  \
# 0                   0.000000        1000.0  201.802084        139.509787
# 4                   0.000000        1200.0  678.334763        244.791237
# 7                   0.000000        2300.0  679.065082        532.033990
# 8                   0.000000        7000.0  688.278568        311.963409
# 14                  0.083333        3000.0  805.647974        989.962866
# ...                      ...           ...         ...               ...
# 8942                0.000000        1000.0   94.488828         86.283101
# 8944                0.000000        4000.0    0.000000       -149.714350
# 8946                0.000000        1000.0  275.861322        438.442488
# 8947                0.000000        1000.0   81.270775         82.418369
# 8948                0.166667         500.0   52.549959         55.755628
#
#       PRC_FULL_PAYMENT  TENURE  Cluster_2  Cluster_3
# 0                 0.00      12          1          0
# 4                 0.00      12          0          0
# 7                 0.00      12          1          1
# 8                 0.00      12          1          1
# 14                0.00      12          0          2
# ...                ...     ...        ...        ...
# 8942              0.25       6          1          0
# 8944              0.00       6          1          1
# 8946              0.00       6          1          0
# 8947              0.25       6          1          0
# 8948              0.25       6          1          0
#
# [2440 rows x 15 columns]

# %% [markdown]
# ### Для двух кластеров

# %%
cluster_col = 'Cluster_2'
exclude_cols = ['CUST_ID', 'Cluster_3', cluster_col]
features = [col for col in df.columns if col not in exclude_cols]

anova_results = []

for feature in features:
    groups = [df[df[cluster_col] == label][feature] for label in df[cluster_col].unique()]

    normal = all(shapiro(group.sample(min(len(group), 1000)))[1] > 0.05 for group in groups)

    if normal:
        stat, p = f_oneway(*groups)
        anova_results.append((feature, p, 'ANOVA'))
    else:
        stat, p = mannwhitneyu(groups[0], groups[1], alternative='two-sided')
        anova_results.append((feature, p, 'Mann-Whitney'))

anova_df = pd.DataFrame(anova_results, columns=['Feature', 'p-value', 'Method'])

significant = anova_df[anova_df['p-value'] < 0.05]

print("Значимые признаки между кластерами:")
print(significant.sort_values('p-value').to_string(index=False))
# Out:
# Значимые признаки между кластерами:
#                Feature       p-value       Method
#    PURCHASES_FREQUENCY 5.586278e-307 Mann-Whitney
#              PURCHASES 8.724757e-292 Mann-Whitney
# INSTALLMENTS_PURCHASES 2.911305e-250 Mann-Whitney
# CASH_ADVANCE_FREQUENCY 6.263357e-210 Mann-Whitney
#           CASH_ADVANCE 2.212449e-201 Mann-Whitney
#                BALANCE 4.711424e-148 Mann-Whitney
#       MINIMUM_PAYMENTS  7.731576e-90 Mann-Whitney
#       ONEOFF_PURCHASES  2.168677e-45 Mann-Whitney
#       PRC_FULL_PAYMENT  1.201590e-32 Mann-Whitney
#      BALANCE_FREQUENCY  1.070606e-19 Mann-Whitney
#               DBSCAN_2  1.298736e-11 Mann-Whitney
#               PAYMENTS  3.241806e-05 Mann-Whitney
#          BIRCH_CLUSTER  4.187612e-03 Mann-Whitney
#           CREDIT_LIMIT  2.950470e-02 Mann-Whitney

# %% [markdown]
# ### Для трех кластеров

# %%
cluster_col = 'Cluster_3'
exclude_cols = ['CUST_ID', 'Cluster_2', cluster_col]
features = [col for col in df.columns if col not in exclude_cols]

anova_results = []

for feature in features:
    groups = [df[df[cluster_col] == label][feature] for label in df[cluster_col].unique()]

    normal = all(shapiro(group.sample(min(len(group), 1000)))[1] > 0.05 for group in groups)

    if normal:
        stat, p = f_oneway(*groups)
        anova_results.append((feature, p, 'ANOVA'))
    else:
        stat, p = kruskal(*groups)
        anova_results.append((feature, p, 'Kraskal-Wollisa'))

anova_df = pd.DataFrame(anova_results, columns=['Feature', 'p-value', 'Method'])

significant = anova_df[anova_df['p-value'] < 0.05]

print("Значимые признаки между кластерами:")
print(significant.sort_values('p-value').to_string(index=False))
# Out:
# Значимые признаки между кластерами:
#                Feature       p-value          Method
#              PURCHASES  0.000000e+00 Kraskal-Wollisa
#    PURCHASES_FREQUENCY 3.040907e-229 Kraskal-Wollisa
# INSTALLMENTS_PURCHASES 3.524101e-226 Kraskal-Wollisa
#                BALANCE 1.867802e-215 Kraskal-Wollisa
# CASH_ADVANCE_FREQUENCY 7.341365e-198 Kraskal-Wollisa
#           CASH_ADVANCE 4.944903e-193 Kraskal-Wollisa
#       MINIMUM_PAYMENTS 2.187971e-154 Kraskal-Wollisa
#               PAYMENTS 2.928930e-145 Kraskal-Wollisa
#       ONEOFF_PURCHASES  2.537093e-71 Kraskal-Wollisa
#           CREDIT_LIMIT  3.678287e-44 Kraskal-Wollisa
#      BALANCE_FREQUENCY  3.917480e-25 Kraskal-Wollisa
#       PRC_FULL_PAYMENT  3.158334e-22 Kraskal-Wollisa
#                 TENURE  7.248340e-08 Kraskal-Wollisa

# %% [markdown]
# # DBSCAN

# %% [markdown]
# Этот алгоритм способен выявлять более сложные формы, чем k-means. В качестве параметров используется e - радиус, определяет максимальное расстояние между двумя точками; min_samples - определяет какое количество точек должно быть в радиусе центровой, чтоб она считалась центром.

# %%
eps_values = np.linspace(1.0, 2.4, 15)
min_samples_values = [5, 6, 7, 8, 9]

best_score = -1
best_params = {}
results = []
best_labels = None

for eps in eps_values:
    for min_samples in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X)
        
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        if n_clusters < 2:
            continue
        
        try:
            sil_score = silhouette_score(X, labels)
            ch_score = calinski_harabasz_score(X[labels != -1], labels[labels != -1])
        except:
            continue
        
        results.append((eps, min_samples, sil_score, ch_score))
        
        if sil_score > best_score:
            best_score = sil_score
            best_params = {'eps': eps, 'min_samples': min_samples}
            best_labels = labels
            best_ch_score = ch_score

print(f"Лучший Silhouette: {best_score:.4f} при eps={best_params['eps']:.2f}, min_samples={best_params['min_samples']}")
print(f"Calinski-Harabasz Score: {best_ch_score:.2f}")
print(f"Количество кластеров: {len(set(best_labels)) - (1 if -1 in best_labels else 0)}")

n_clusters = len(set(best_labels)) - (1 if -1 in best_labels else 0)
cluster_col_name = f'DBSCAN_{n_clusters}'
df[cluster_col_name] = best_labels
# Out:
# Лучший Silhouette: 0.2016 при eps=2.30, min_samples=5
# Calinski-Harabasz Score: 7.66
# Количество кластеров: 2

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=best_labels, alpha=0.7)
plt.title(f'DBSCAN Clusters (eps={best_params["eps"]:.2f}, min_samples={best_params["min_samples"]}) на PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %% [markdown]
# ## Визуализация влияния признаков на работу модели

# %%
df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 4      817.714335           1.000000      16.00             16.00
# 7     1823.652743           1.000000     436.20              0.00
# 8     1014.926473           1.000000     861.49            661.49
# 14    2772.772734           1.000000       0.00              0.00
# ...           ...                ...        ...               ...
# 8942    40.829749           1.000000     113.28              0.00
# 8944   193.571722           0.833333    1012.73           1012.73
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 4                       0.00      0.000000             0.083333
# 7                     436.20      0.000000             1.000000
# 8                     200.00      0.000000             0.333333
# 14                      0.00    346.811390             0.000000
# ...                      ...           ...                  ...
# 8942                  113.28      0.000000             1.000000
# 8944                    0.00      0.000000             0.333333
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
#
#       CASH_ADVANCE_FREQUENCY  CREDIT_LIMIT    PAYMENTS  MINIMUM_PAYMENTS  \
# 0                   0.000000        1000.0  201.802084        139.509787
# 4                   0.000000        1200.0  678.334763        244.791237
# 7                   0.000000        2300.0  679.065082        532.033990
# 8                   0.000000        7000.0  688.278568        311.963409
# 14                  0.083333        3000.0  805.647974        989.962866
# ...                      ...           ...         ...               ...
# 8942                0.000000        1000.0   94.488828         86.283101
# 8944                0.000000        4000.0    0.000000       -149.714350
# 8946                0.000000        1000.0  275.861322        438.442488
# 8947                0.000000        1000.0   81.270775         82.418369
# 8948                0.166667         500.0   52.549959         55.755628
#
#       PRC_FULL_PAYMENT  TENURE  Cluster_2  Cluster_3  DBSCAN_2
# 0                 0.00      12          1          0         0
# 4                 0.00      12          0          0         0
# 7                 0.00      12          1          1         0
# 8                 0.00      12          1          1         0
# 14                0.00      12          0          2         0
# ...                ...     ...        ...        ...       ...
# 8942              0.25       6          1          0         0
# 8944              0.00       6          1          1        -1
# 8946              0.00       6          1          0         0
# 8947              0.25       6          1          0         0
# 8948              0.25       6          1          0        -1
#
# [2440 rows x 16 columns]

# %%
cluster_col = 'DBSCAN_2'
unnecessary = ['Cluster_2', 'Cluster_3', 'DBSCAN_2', 'CUST_ID']

df_filtered = df[df[cluster_col] != -1].copy()
features_to_plot = [col for col in df.columns if col not in unnecessary]

for feature in features_to_plot:
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    sns.boxplot(data=df_filtered, x=cluster_col, y=feature, ax=axes[0])
    axes[0].set_title(f'Boxplot: {feature} ({cluster_col})')
    axes[0].grid(True)

    sns.barplot(data=df_filtered, x=cluster_col, y=feature, ax=axes[1], estimator='mean')
    axes[1].set_title(f'Mean Barplot: {feature} ({cluster_col})')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # ANOVA

# %%
cluster_col = 'DBSCAN_2'
exclude_cols = ['CUST_ID', 'Cluster_3', cluster_col, 'Cluster_2']
features = [col for col in df.columns if col not in exclude_cols]

anova_results = []

for feature in features:
    groups = [df[df[cluster_col] == label][feature] for label in df[cluster_col].unique()]

    normal = all(shapiro(group.sample(min(len(group), 1000)))[1] > 0.05 for group in groups)

    if normal:
        stat, p = f_oneway(*groups)
        anova_results.append((feature, p, 'ANOVA'))
    else:
        stat, p = mannwhitneyu(groups[0], groups[1], alternative='two-sided')
        anova_results.append((feature, p, 'Mann-Whitney'))

anova_df = pd.DataFrame(anova_results, columns=['Feature', 'p-value', 'Method'])

significant = anova_df[anova_df['p-value'] < 0.05]

print("Значимые признаки между кластерами:")
print(significant.sort_values('p-value').to_string(index=False))
# Out:
# Значимые признаки между кластерами:
#                Feature      p-value       Method
#              PURCHASES 7.955809e-33 Mann-Whitney
#       ONEOFF_PURCHASES 5.685553e-22 Mann-Whitney
# INSTALLMENTS_PURCHASES 1.607926e-19 Mann-Whitney
#      BALANCE_FREQUENCY 8.972397e-16 Mann-Whitney
#    PURCHASES_FREQUENCY 2.690412e-14 Mann-Whitney
#       PRC_FULL_PAYMENT 1.748904e-13 Mann-Whitney
#                 TENURE 1.725355e-09 Mann-Whitney
#               PAYMENTS 2.011299e-09 Mann-Whitney
#           CREDIT_LIMIT 2.270212e-08 Mann-Whitney
#           CASH_ADVANCE 3.609718e-04 Mann-Whitney
# CASH_ADVANCE_FREQUENCY 4.626768e-04 Mann-Whitney

# %% [markdown]
# # BIRCH

# %% [markdown]
# Этот алгоритм построен на основе CF-дерева, где каждая ветка это набор похожих точек, которые хрнаятся в формате (N, LS, SS) , то есть (количество точек в узле, сумма координат, сумма квадратов координат), это позволяет задействовать меньше памяти и быстро вычислять центр, разброс и расстояние между кластерами. Если в узле оказывается слишком много ветвей, то расщипляется на более мелкие уровни. При принятии решения можно использовать каждый лист как отдельный кластер, либо применить к листьям K-means.

# %% [markdown]
# ### Плюсы:
# Хорошо определяет сферические формы кластеров, быстро работает, занимает мало памяти, эффективен для больших данных, можно использовать для входа K-means
#
# ### Минусы
# Радиус кластеров (treashold) определяется вручную подбором, плохо работает с нестандартным видом кластера, не распознает выбросы,

# %%
k = 5
neigh = NearestNeighbors(n_neighbors=k)
neigh.fit(X)
distances, indices = neigh.kneighbors(X)

k_distances = distances[:, -1]
k_distances_sorted = np.sort(k_distances)

plt.figure(figsize=(8,5))
plt.plot(k_distances_sorted)
plt.title(f'k-Distance Graph (k={k})')
plt.xlabel('Точки, отсортированные по расстоянию')
plt.ylabel(f'Расстояние до {k}-го соседа')
plt.grid()
plt.show()

# %%
threshold = np.percentile(k_distances, 98)
print("Порог для BIRCH по 98%-квантилю:", threshold)
# Out:
# Порог для BIRCH по 98%-квантилю: 3.1205906996999757

# %%
birch_model = Birch(threshold=threshold, n_clusters=2)
birch_model.fit(X)

labels = birch_model.labels_
df['BIRCH_CLUSTER'] = labels

# %%
df['BIRCH_CLUSTER'].value_counts()
# Out:
# BIRCH_CLUSTER
# 0    2433
# 1       7
# Name: count, dtype: int64

# %%
score = silhouette_score(X, df['BIRCH_CLUSTER'])
print("Silhouette Score (cleaned):", round(score, 4))

mask = best_labels != -1
ch_score = calinski_harabasz_score(X[mask], best_labels[mask])

print(f"Calinski-Harabasz Score: {ch_score:.2f}")
# Out:
# Silhouette Score (cleaned): 0.4155
# Calinski-Harabasz Score: 7.66

# %%
threshold_values = np.linspace(0.5, 3.5, 20)
n_cluster_values = [2, 3, 4, 5, 6, 7]

results = []
best_score = -1
best_labels = None

for threshold in threshold_values:
    for n_clusters in n_cluster_values:
        birch = Birch(threshold=threshold, n_clusters=n_clusters)
        labels = birch.fit_predict(X)

        if len(set(labels)) < 2:
            continue  
        
        try:
            sil_score = silhouette_score(X, labels)
            ch_score = calinski_harabasz_score(X, labels)
        except:
            continue
        
        results.append((threshold, n_clusters, sil_score, ch_score))

        if sil_score > best_score:
            best_score = sil_score
            best_params = {'threshold': threshold, 'n_clusters': n_clusters}
            best_labels = labels
            best_ch = ch_score

print(f"Лучший Silhouette: {best_score:.4f} при threshold={best_params['threshold']:.3f}, n_clusters={best_params['n_clusters']}")
print(f"Calinski-Harabasz Score: {best_ch:.2f}")
# Out:
# Лучший Silhouette: 0.3109 при threshold=3.342, n_clusters=2
# Calinski-Harabasz Score: 79.19

# %%
X_pca = PCA(n_components=2).fit_transform(X)

plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=best_labels, cmap='viridis')
plt.title(f"BIRCH Clustering (threshold = {threshold})")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.grid(True)
plt.show()

# %% [markdown]
# # Метрики
#
# - **Silhouette Score** показывает насколько каждый объект ближе к своему кластеру, чем к чужому. (чем ближе к 1, тем лучше)
# - **Calinski-Harabasz Index (CH-индекс)** Он измеряет, насколько кластеры хорошо отделены друг от друга и насколько они внутри себя компактны. (чем больше, тем лучше)

# %% [markdown]
# # Резюме по результатам метрик:

# %% [markdown]
# | Метод кластеризации | Кол-во кластеров | Silhouette Score | Calinski-Harabasz Index |
# |----------------------|------------------|-------------------|--------------------------|
# | KMeans          | 2                | 0.1880             | 531.35                  |
# | DBSCAN          | 2                | 0.2016             | 7.66                    |
# | BIRCH          | 2                | 0.4155             | 7.66                   |
